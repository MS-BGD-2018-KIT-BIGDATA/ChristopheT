# %%
import pandas as pd
# telechargement des données
# http://www.data.drees.sante.gouv.fr/TableViewer/tableView.aspx?ReportId=2489

data = pd.read_csv('rpps-medecins.csv', sep=',', header = 3, encoding='latin_1')
data = data.dropna(axis=0, how='any')
data.head()
# Out:
#                             Unnamed: 0                  ZONE INSCRIPT  \
# 1  Ensemble des spécialités d'exercice  Ensemble des modes d'exercice
# 2  Ensemble des spécialités d'exercice             Libéraux exclusifs
# 3  Ensemble des spécialités d'exercice                         Mixtes
# 4  Ensemble des spécialités d'exercice          Salariés hospitaliers
# 5  Ensemble des spécialités d'exercice                Autres salariés
#
#    FRANCE ENTIERE  FRANCE Métropolitaine  DOM-COM  \
# 1        223571.0               218018.0   5553.0
# 2        105872.0               103182.0   2690.0
# 3         24134.0                23824.0    310.0
# 4         66596.0                64561.0   2035.0
# 5         26969.0                26451.0    518.0
#
#    Alsace-Champagne-Ardenne-Lorraine  Aquitaine-Limousin-Poitou-Charentes  \
# 1                            17789.0                              19745.0
# 2                             8327.0                              10289.0
# 3                             2183.0                               1890.0
# 4                             5317.0                               5323.0
# 5                             1962.0                               2243.0
#
#    Auvergne-Rhône-Alpes  Bourgogne-Franche-Comté  Bretagne      ...        \
# 1               26533.0                   8310.0   10400.0      ...
# 2               12304.0                   3604.0    5016.0      ...
# 3                2892.0                   1072.0     939.0      ...
# 4                8164.0                   2647.0    3243.0      ...
# 5                3173.0                    987.0    1202.0      ...
#
#    91 - Essonne  92 - Hauts-de-Seine  93 - Seine-Saint-Denis  \
# 1        3288.0               6457.0                  4247.0
# 2        1661.0               2826.0                  1680.0
# 3         320.0                596.0                   428.0
# 4         899.0               1811.0                  1343.0
# 5         408.0               1224.0                   796.0
#
#    94 - Val-de-Marne  95 - Val-dOise  971 - Guadeloupe  972 - Martinique  \
# 1             5207.0           3169.0            1071.0            1034.0
# 2             1754.0           1429.0             507.0             469.0
# 3              643.0            412.0              84.0              97.0
# 4             2182.0            940.0             370.0             380.0
# 5              628.0            388.0             110.0              88.0
#
#    973 - Guyane  974 - La Réunion  976 - Mayotte
# 1         578.0            2683.0          187.0
# 2         175.0            1505.0           34.0
# 3          29.0              97.0            3.0
# 4         302.0             856.0          127.0
# 5          72.0             225.0           23.0
#
# [5 rows x 124 columns]
